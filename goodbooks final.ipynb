# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Purvitha S\OneDrive\good books\books.csv")

# %%
df.isnull().sum()
# Out:
# book_id                         0
# goodreads_book_id               0
# best_book_id                    0
# work_id                         0
# books_count                     0
# isbn                          700
# isbn13                        585
# authors                         0
# original_publication_year      21
# original_title                585
# title                           0
# language_code                1084
# average_rating                  0
# ratings_count                   0
# work_ratings_count              0
# work_text_reviews_count         0
# ratings_1                       0
# ratings_2                       0
# ratings_3                       0
# ratings_4                       0
# ratings_5                       0
# image_url                       0
# small_image_url                 0
# dtype: int64

# %%
df = df.drop(columns=['isbn', 'isbn13', 'image_url', 'small_image_url'], errors='ignore')

# %%
df
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           4               2657          2657   3275794          487
# 4           5               4671          4671    245494         1356
# ...       ...                ...           ...       ...          ...
# 9995     9996            7130616       7130616   7392860           19
# 9996     9997             208324        208324   1084709           19
# 9997     9998              77431         77431   2393986           60
# 9998     9999            8565083       8565083  13433613            7
# 9999    10000               8914          8914     11817           31
#
#                           authors  original_publication_year  \
# 0                 Suzanne Collins                     2008.0
# ...

# %%
df.isnull().sum()
# Out:
# book_id                         0
# goodreads_book_id               0
# best_book_id                    0
# work_id                         0
# books_count                     0
# isbn                          700
# isbn13                          0
# authors                         0
# original_publication_year       0
# original_title                585
# title                           0
# language_code                1084
# average_rating                  0
# ratings_count                   0
# work_ratings_count              0
# work_text_reviews_count         0
# ratings_1                       0
# ratings_2                       0
# ratings_3                       0
# ratings_4                       0
# ratings_5                       0
# image_url                       0
# small_image_url                 0
# dtype: int64

# %%
df['books_count'] = pd.to_datetime(df['books_count'], dayfirst=True)

# %%
df['Month'] = df['books_count'].dt.to_period('M')
df['Month']
# Out:
# 0       1970-01
# 1       1970-01
# 2       1970-01
# 3       1970-01
# 4       1970-01
#          ...
# 9995    1970-01
# 9996    1970-01
# 9997    1970-01
# 9998    1970-01
# 9999    1970-01
# Name: Month, Length: 10000, dtype: period[M]

# %%
df.describe()
# Out:
#            book_id  goodreads_book_id  best_book_id       work_id  \
# count  10000.00000       1.000000e+04  1.000000e+04  1.000000e+04
# mean    5000.50000       5.264697e+06  5.471214e+06  8.646183e+06
# min        1.00000       1.000000e+00  1.000000e+00  8.700000e+01
# 25%     2500.75000       4.627575e+04  4.791175e+04  1.008841e+06
# 50%     5000.50000       3.949655e+05  4.251235e+05  2.719524e+06
# 75%     7500.25000       9.382225e+06  9.636112e+06  1.451775e+07
# max    10000.00000       3.328864e+07  3.553423e+07  5.639960e+07
# std     2886.89568       7.575462e+06  7.827330e+06  1.175106e+07
#
#                          books_count        isbn13  original_publication_year  \
# count                          10000  1.000000e+04               10000.000000
# mean   1970-01-01 00:00:00.000000075  9.755044e+12                1981.987674
# min    1970-01-01 00:00:00.000000001  1.951703e+08               -1750.000000
# ...

# %%
avg_rating_by_author = df.groupby('authors')['average_rating'].mean().sort_values(ascending=False)
print("\nAverage Rating by Author:")
print(avg_rating_by_author.head(10))

ratings_count_by_author = df.groupby('authors')['ratings_count'].sum().sort_values(ascending=False)
print("\nTotal Ratings by Author:")
print(ratings_count_by_author.head(10))
# Out:
# Average Rating by Author:
# authors
# Anonymous, Lane T. Dennis, Wayne A. Grudem                                                                                                                                                                                  4.760000
# Bill Watterson                                                                                                                                                                                                              4.710833
# Anonymous, Ronald A. Beers, Ronald A. Beers                                                                                                                                                                                 4.670000
# Neil Gaiman, Mike Dringenberg, Chris Bachalo, Michael Zulli, Kelly Jones, Charles Vess, Colleen Doran, Malcolm Jones Iii, Steve Parkhouse, Daniel Vozzo, Lee Loughridge, Steve Oliff, Todd Klein, Dave Mckean, Sam Kieth    4.650000
# ...

# %%
correlation_matrix = df[['ratings_count', 'average_rating']].corr()

print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                 ratings_count  average_rating
# ratings_count         1.00000         0.04499
# average_rating        0.04499         1.00000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
df = pd.read_csv(r"C:\Users\Purvitha S\OneDrive\good books\books.csv")
df = df.dropna(subset=['authors', 'ratings_count', 'average_rating'])

print("\nAverage Rating by Author:")
print(df.groupby('authors')['average_rating'].mean().sort_values(ascending=False).head(10))

print("\nAverage Ratings Count by Language Code:")
print(df.groupby('language_code')['ratings_count'].mean().sort_values(ascending=False).head(10))

if 'publisher' in df.columns:
    print("\nAverage Rating by Publisher:")
    print(df.groupby('publisher')['average_rating'].mean().sort_values(ascending=False).head(10))
# Out:
# Average Rating by Author:
# authors
# Anonymous, Lane T. Dennis, Wayne A. Grudem                                                                                                                                                                                  4.760000
# Bill Watterson                                                                                                                                                                                                              4.710833
# Anonymous, Ronald A. Beers, Ronald A. Beers                                                                                                                                                                                 4.670000
# Neil Gaiman, Mike Dringenberg, Chris Bachalo, Michael Zulli, Kelly Jones, Charles Vess, Colleen Doran, Malcolm Jones III, Steve Parkhouse, Daniel Vozzo, Lee Loughridge, Steve Oliff, Todd Klein, Dave McKean, Sam Kieth    4.650000
# ...

# %%
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(8, 5))
df.groupby('authors')['average_rating'].mean().sort_values(ascending=False).head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Authors by Average Rating')
plt.ylabel('Average Rating')
plt.xlabel('Author')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Purvitha S\AppData\Local\Temp\ipykernel_3764\657171159.py:7: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
plt.figure(figsize=(8, 5))
df['original_publication_year'].value_counts().sort_index().plot(kind='line', marker='o', color='green')
plt.title('Books Published per Year')
plt.ylabel('Number of Books')
plt.xlabel('Publication Year')
plt.tight_layout()
plt.show()

# %%
df.nlargest(10, 'ratings_count').set_index('original_title')['ratings_count'].plot(kind='barh', color='orange')
plt.title('Top 10 Most Rated Books')
plt.xlabel('Ratings Count')
plt.ylabel('Book Title')
plt.tight_layout()
plt.show()

# %%
df.plot(kind='scatter', x='ratings_count', y='average_rating', alpha=0.5)
plt.title('Ratings Count vs Average Rating')
plt.xlabel('Ratings Count')
plt.ylabel('Average Rating')
plt.tight_layout()
plt.show()

# %%
df['average_rating'].plot(kind='hist', bins=20, edgecolor='black')
plt.title('Distribution of Average Ratings')
plt.xlabel('Average Rating')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# %%
numeric_cols = df.select_dtypes(include='number').columns

plt.figure(figsize=(10,6))
sns.boxplot(data=df[numeric_cols])
plt.title('Box Plots for Numeric Columns')
plt.xticks(rotation=45)
plt.show()
